# %% [markdown]
# Parse the UC file

# %%
load pandas as pd
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File /cvmfs/hpc.ucdavis.edu/sw/conda/environments/jupyterlab-4/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3909, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3908 try:                                              # User namespace
# -> 3909     codeobj = eval(target, self.user_ns)
#    3910 except Exception as e:
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('load', 'pandas as pd ')
#
# ...

# %%
uc_cols = ["type","cluster","qlen","pct_id","strand","x1","x2","cigar","query","target"]
uc = pd.read_csv("closed_ref_map.uc", sep="\t", header=None, names=uc_cols)

# Keep only hit lines
hits = uc[uc["type"] == "H"][["query", "target", "pct_id"]].copy()
hits.columns = ["asv_id", "gtdb_ref", "pct_identity"]

print(f"Total ASVs with hits: {len(hits)}")
hits.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 uc_cols = ["type","cluster","qlen","pct_id","strand","x1","x2","cigar","query","target"]
# ----> 2 uc = pd.read_csv("closed_ref_map.uc", sep="\t", header=None, names=uc_cols)
#       4 # Keep only hit lines
#       5 hits = uc[uc["type"] == "H"][["query", "target", "pct_id"]].copy()
#
# NameError: name 'pd' is not defined
